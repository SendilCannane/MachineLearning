# %%
import pandas as pd
#import quandl
df = pd.read_excel('D://Python//Lab//Homeprice.xlsx', index = False)
df
# Out:
#                Town  Area   Price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     657             result = expressions.evaluate(op, str_rep, x, y,
# --> 658                                           raise_on_error=True, **eval_kwargs)
#     659         except TypeError:
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     210         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 211                          **eval_kwargs)
#     212     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
#     121     if result is None:
# --> 122         result = _evaluate_standard(op, op_str, a, b, raise_on_error)
#     123
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     681             with np.errstate(all='ignore'):
# --> 682                 return na_op(lvalues, rvalues)
#     683         except Exception:
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     663                 mask = notnull(x) & notnull(y)
# --> 664                 result[mask] = op(x[mask], _values_from_object(y[mask]))
#     665             elif isinstance(x, np.ndarray):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d488a5181465> in <module>()
# ----> 1 df3 = df.max() - df.min()
#       2 df3
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name, na_op)
#     719                 lvalues = lvalues.values
#     720
# --> 721         result = wrap_results(safe_na_op(lvalues, rvalues))
#     722         return construct_result(
#     723             left,
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     690                 if is_object_dtype(lvalues):
#     691                     return libalgos.arrmap_object(lvalues,
# --> 692                                                   lambda x: op(x, rvalues))
#     693             raise
#     694
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#     690                 if is_object_dtype(lvalues):
#     691                     return libalgos.arrmap_object(lvalues,
# --> 692                                                   lambda x: op(x, rvalues))
#     693             raise
#     694
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
dummies=pd.get_dummies(df.Town)
dummies
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#                Town  Area   Price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# 11      robinsville  3100  620000                0            1             0
# 12      robinsville  3600  695000                0            1             0

# %%
final = merged.drop(['Town','west windsor'], axis='columns')
final
# Out:
#     Area   Price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %%
df3 = final.max() - final.min()
df3
# Out:
# Area                 1400
# Price              175000
# monroe township         1
# robinsville             1
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(n_jobs = -1)

# %%
x=final.drop('Price',axis='columns')
x
# Out:
#     Area  monroe township  robinsville
# 0   2600                1            0
# 1   3000                1            0
# 2   3200                1            0
# 3   3600                1            0
# 4   4000                1            0
# 5   2600                0            0
# 6   2800                0            0
# 7   3300                0            0
# 8   3600                0            0
# 9   2600                0            1
# 10  2900                0            1
# 11  3100                0            1
# 12  3600                0            1

# %%
y=final.Price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: Price, dtype: int64

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %%
model.predict([[2800,0,1]])
# Out:
# array([ 590775.63964739])

# %%
model.predict([[3400,0,0]])
# Out:
# array([ 681241.66845839])

# %%
model.score(x,y)
# Out:
# 0.95739290372218733

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dfle=df
dfle.Town=le.fit_transform(dfle.Town)
dfle
# Out:
#     Town  Area   Price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
x=dfle[['Town','Area']].values

# %%
x
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 4000],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]], dtype=int64)

# %%
y=dfle.Price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: Price, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(categorical_features=[0])

# %%
x=ohe.fit_transform(x).toarray()
x
# Out:
# array([[  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   2.60000000e+03],
#        [  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   3.00000000e+03],
#        [  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   3.20000000e+03],
#        [  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   3.60000000e+03],
#        [  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   4.00000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   2.60000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   2.80000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   3.30000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   3.60000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   2.60000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   2.90000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   3.10000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   3.60000000e+03]])

# %%
x=x[:,1:]
x
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   2.60000000e+03],
#        [  0.00000000e+00,   0.00000000e+00,   3.00000000e+03],
#        [  0.00000000e+00,   0.00000000e+00,   3.20000000e+03],
#        [  0.00000000e+00,   0.00000000e+00,   3.60000000e+03],
#        [  0.00000000e+00,   0.00000000e+00,   4.00000000e+03],
#        [  0.00000000e+00,   1.00000000e+00,   2.60000000e+03],
#        [  0.00000000e+00,   1.00000000e+00,   2.80000000e+03],
#        [  0.00000000e+00,   1.00000000e+00,   3.30000000e+03],
#        [  0.00000000e+00,   1.00000000e+00,   3.60000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   2.60000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   2.90000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   3.10000000e+03],
#        [  1.00000000e+00,   0.00000000e+00,   3.60000000e+03]])

# %%
model2=LinearRegression()
model2.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model2.predict([[0,0,3700]])
# Out:
# array([ 679296.92539239])

# %%
df1 = pd.read_excel('D://Python//Lab//Homeprice.xlsx', index = False)
df1
df1.drop(['Area'],1)
# Out:
#                Town   Price
# 0   monroe township  550000
# 1   monroe township  565000
# 2   monroe township  610000
# 3   monroe township  680000
# 4   monroe township  725000
# 5      west windsor  585000
# 6      west windsor  615000
# 7      west windsor  650000
# 8      west windsor  710000
# 9       robinsville  575000
# 10      robinsville  600000
# 11      robinsville  620000
# 12      robinsville  695000
